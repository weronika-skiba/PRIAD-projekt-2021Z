# %% [markdown]
# # Projekt - Podstawy Reprezentacji i analizy danych - 2021Z

# %% [markdown]
# Temat projektu: Ocena jakości wina

# %% [markdown]
# Autorzy: Weronika Skiba (311465) i Daniel Ślusarczyk (...)

# %% [markdown]
# Cel projektu: Dokonanie oceny jakości wina na podstawie podanych dla niego atrybutów z wykorzystaniem uczenia maszynowego

# %% [markdown]
# Krótki opis zagadnienia

# %% [markdown]
# 1.Pobranie potrzebnych bibliotek:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 2.Utworzenie ramek danych:

# %%
ww_org = pd.read_excel('winequality-white.xlsx')
ww = ww_org.drop(columns = ['quality'])
print(ww.head())
print(ww.describe())
# Out:
#          fixed acidity volatile acidity citric acid       residual sugar  \
# 0                    7             0.27        0.36  2022-07-20 00:00:00
# 1  2022-03-06 00:00:00              0.3        0.34  2022-06-01 00:00:00
# 2  2022-01-08 00:00:00             0.28         0.4  2022-09-06 00:00:00
# 3  2022-02-07 00:00:00             0.23        0.32  2022-05-08 00:00:00
# 4  2022-02-07 00:00:00             0.23        0.32  2022-05-08 00:00:00
#
#    chlorides free sulfur dioxide  total sulfur dioxide  density  \
# 0      0.045                  45                 170.0   1.0010
# 1      0.049                  14                 132.0   0.9940
# 2      0.050                  30                  97.0   0.9951
# 3      0.058                  47                 186.0   0.9956
# 4      0.058                  47                 186.0   0.9956
#
#                     pH sulphates              alcohol
# 0                    3      0.45  2022-08-08 00:00:00
# ...

# %% [markdown]
# 3.Upewnienie się, że ramki nie zawierają wartości null:

# %% [markdown]
# 4.Utworzenie macierzy histogramów:

# %%
sns.pairplot(ww, kind="scatter")

# %% [markdown]
# 5.Wizualizacja korelacji atrybutów w formie mapy ciepła:

# %%
plt.show()
sns.heatmap(ww.corr(),annot = ww.corr())
# Out:
# <AxesSubplot:>
